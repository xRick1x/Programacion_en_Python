# %% [markdown]
# <a href="https://colab.research.google.com/github/xRick1x/Programacion_en_Python/blob/main/Tarea_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def imprimir_multiplos():
    M = int(input("Ingrese el valor máximo M: "))
    n = int(input("Ingrese el valor del múltiplo n: "))
    for i in range(n, M, n):
        print(i)

imprimir_multiplos()
# Out:
# Streaming output truncated to the last 5000 lines.
# 50000
# 50010
# 50020
# 50030
# 50040
# 50050
# 50060
# 50070
# 50080
# 50090
# 50100
# 50110
# 50120
# 50130
# 50140
# 50150
# 50160
# 50170
# 50180
# 50190
# 50200
# 50210
# 50220
# 50230
# 50240
# 50250
# 50260
# 50270
# 50280
# 50290
# 50300
# 50310
# 50320
# 50330
# 50340
# 50350
# 50360
# 50370
# 50380
# 50390
# 50400
# 50410
# 50420
# 50430
# 50440
# 50450
# 50460
# 50470
# 50480
# 50490
# 50500
# 50510
# 50520
# 50530
# 50540
# 50550
# 50560
# 50570
# 50580
# 50590
# 50600
# 50610
# 50620
# 50630
# 50640
# 50650
# 50660
# 50670
# 50680
# 50690
# 50700
# 50710
# 50720
# 50730
# 50740
# 50750
# 50760
# 50770
# 50780
# 50790
# 50800
# 50810
# 50820
# 50830
# 50840
# 50850
# 50860
# 50870
# 50880
# 50890
# 50900
# 50910
# 50920
# 50930
# 50940
# 50950
# 50960
# 50970
# 50980
# 50990
# 51000
# 51010
# 51020
# 51030
# 51040
# 51050
# 51060
# 51070
# 51080
# 51090
# 51100
# 51110
# 51120
# 51130
# 51140
# 51150
# 51160
# 51170
# ...
